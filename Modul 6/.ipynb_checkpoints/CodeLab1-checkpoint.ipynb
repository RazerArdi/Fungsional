# %% [markdown]
# ### CODELAB1

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter

# %%
# Buka gambar
img = Image.open('kucing.jpg')

# %%
# filter kontur
image_after1 = img.filter(ImageFilter.CONTOUR)

# filter blur
image_after2 = img.filter(ImageFilter.BLUR)

# %%
# figure
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Tampilkan gambar dengan filter kontur (subplot)
axes[0].imshow(image_after1)
axes[0].set_title('Gambar dengan Filter Kontur')
axes[0].axis('off')

# Tampilkan gambar dengan filter blur (Subplot)
axes[1].imshow(image_after2)
axes[1].set_title('Gambar dengan Filter Blur')
axes[1].axis('off') 

plt.show()
